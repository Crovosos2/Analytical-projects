# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Александр, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам специалиста по работе с данными. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# критичные ошибки, которые обязательно нужно исправить.
# </div>
#
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# # Обучение с учителем: качество модели

# %% [markdown]
# ## Описание исследования
# Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.<br><br>
# «В один клик» — современная компания, поэтому её руководство не хочет принимать решения просто так — только на основе анализа данных и бизнес-моделирования. У компании есть небольшой отдел цифровых технологий, и вам предстоит побыть в роли стажёра в этом отделе. <br><br>
# Поручено разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.

# %% [markdown]
# ## Цель исследования
# Изучить данные и определить критерии, которые позволят обучить предсказательную модель под задачу заказчика.

# %% [markdown]
# ## Задачи исследования
# Нужно промаркировать уровень финансовой активности постоянных покупателей. В компании принято выделять два уровня активности: «снизилась», если клиент стал покупать меньше товаров, и «прежний уровень».

# %% [markdown]
# ## Исходные данные
#
# `market_file.csv`
#
# `market_money.csv`
#
# `market_time.csv`
#
# `money.csv`
#
# Файл `market_file.csv` содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
#
# Описание таблицы:
#
# - `id` — номер покупателя в корпоративной базе данных;
# - `Покупательская активность` — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень»;
# - `Тип сервиса` — уровень сервиса, например «премиум» и «стандарт»;
# - `Разрешить сообщать` — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
# - `Маркет_актив_6_мес` — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента;
# - `Маркет_актив_тек_мес` — количество маркетинговых коммуникаций в текущем месяце;
# - `Длительность` — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
# - `Акционные_покупки` — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
# - `Популярная_категория` — самая популярная категория товаров у покупателя за последние 6 месяцев.
# - `Средний_просмотр_категорий_за_визит` — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
# - `Неоплаченные_продукты_штук_квартал` — общее число неоплаченных товаров в корзине за последние 3 месяца.
# - `Ошибка_сервиса` — число сбоев, которые коснулись покупателя во время посещения сайта.
# - `Страниц_за_визит` — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.
#
#
# Файл `market_money.csv` содержит данные о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
#
# Описание таблицы:
#
# - `id` — номер покупателя в корпоративной базе данных;
# - `Период` — название периода, во время которого зафиксирована выручка. Например, 'текущий_месяц' или 'предыдущий_месяц';
# - `Выручка` — сумма выручки за период;
#
#
# Файл `market_time.csv` содержит данные о времени (в минутах), которое покупатель провёл на сайте в течение периода.
#
# Описание таблицы:
#
# - `id` — номер покупателя в корпоративной базе данных;
# - `Период` — название периода, во время которого зафиксировано общее время;
# - `минут` — значение времени, проведённого на сайте, в минутах;
#
#
# Файл `money.csv` содержит данные о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
#
# Описание таблицы:
#
# - `id` — номер покупателя в корпоративной базе данных;
# - `Прибыль` — значение прибыли;

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хорошее вступление!
#
# В нём есть всё, что необходимо, чтобы понять суть проекта с первых строк отчёта!

# %% [markdown]
# ## Шаг 1. Загрузка данных

# %% [markdown]
# ### Подключение библиотек

# %%
# !pip install phik -q;

# %%
# !pip install shap;

# %%
# !pip install -U scikit-learn;

# %%
import pandas as pd
import numpy as np
import phik
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["figure.figsize"] = (10,6)


from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score, f1_score
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler, RobustScaler, \
LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.model_selection import RandomizedSearchCV
import shap
from sklearn.dummy import DummyClassifier

# %%
#!pip install -U scikit-learn;

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали - отлично!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
# Ты импортируешь библиотеки и модули, которые не используешь в проекте - так делать не стоит, так как ты забиваешь окружение лишними  инструментами.
#
# В блоке импорта стоит оставить только то, что реально используется в проекте.
# </div>

# %% [markdown]
# ### Загрузка данных

# %%
market_file = pd.read_csv('/datasets/market_file.csv')
market_money = pd.read_csv('/datasets/market_money.csv')
market_time = pd.read_csv('/datasets/market_time.csv')
money = pd.read_csv('/datasets/money.csv', sep=';')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Данные загрузили.
#
# При считывании данных из файла здорово перестраховывать себя от ошибок, связанных, например, с неверным указанием пути к файлу. А иногда бывает, что работаешь с файлом локально, выгружаешь его на сервер, ожидая, что он будет принимать данные, которые лежат на том же сервере, а код падает с ошибкой, потому что путь к файлу не поменялся с локального на серверный.
#
# Для этого, например, можно использовать конструкцию `try-except`: сначала пробуешь локальный путь, при возникновении ошибки используется серверный путь (подробнее можешь почитать тут: https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html).
#
# Но еще лучше использовать библиотеку `os` - её использование позволит тебе проверять существование указанных директорий (что может быть актуально при одновременной работа на локальном и сетевом окружении) и загружать данные из существующей директории, избегая ошибок. Как пример:
#
#     import os
#
#     pth1 = '/folder_1/data.csv'
#     pth2 = '/folder_2/data.csv'
#
#     if os.path.exists(pth1):
#         query_1 = pd.read_csv(pth1)
#     elif os.path.exists(pth2):
#         query_1 = pd.read_csv(pth2)
#     else:
#         print('Something is wrong')
#
# Ещё на этапе считывания данных можно спарсить дату: за это действие отвечает параметр `parse_dates` метода `read_csv()`, в него нужно передать список с названием полей-дат, и в большинстве случаев дата будет корректно преобразована в нужный формат сразу:)
# Также на этапе считывания данных можно задать индекс-столбец - за это действие отвечает параметр `index_col`.

# %%
df_list = [market_file, market_money, market_time, money]
for df_l in df_list:
    display(df_l.head())
    print()
# Out:
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
#   Популярная_категория  Средний_просмотр_категорий_за_визит  \
# ...

# %% [markdown]
# ### Вывод:
# С данными ознакомился

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %%
money = money.applymap(lambda x: x.replace(',', '.') if isinstance(x, str) else x)

# %%
for df_l in df_list:
    print(df_l.info())
    print()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  Неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %%
money['Прибыль'] = money['Прибыль'].astype(float)

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Пропусков не видно. "Прибыль" из датафрейма money приведены к верному типу. Данные в остальных датафреймах нужного типа.</font>
# </div>

# %%
df_list = [market_file, market_money, market_time, money]
for df_l in df_list:
    print(f'Дубликатов: {df_l.duplicated().sum()}')
    print()
# Out:
# Дубликатов: 0
#
# Дубликатов: 0
#
# Дубликатов: 0
#
# Дубликатов: 0

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Дубликаты так же не обнаружены.</font>
# </div>

# %% [markdown]
# ### Вывод:
# Пропусков не обнаружено. Дубликаты не обнаружены. Столбец "Прибыль" в датафрейме money приведет к типу float

# %%
for df_l in df_list:
    str_columns = df_l.select_dtypes(include='object').columns
    for col in str_columns:
        print(df_l[col].value_counts())
        print()
# Out:
# Прежний уровень    802
# Снизилась          498
# Name: Покупательская активность, dtype: int64
#
# стандарт     914
# премиум      376
# стандартт     10
# Name: Тип сервиса, dtype: int64
#
# да     962
# нет    338
# Name: Разрешить сообщать, dtype: int64
#
# Товары для детей                        330
# Домашний текстиль                       251
# Косметика и аксесуары                   223
# Техника для красоты и здоровья          184
# Мелкая бытовая техника и электроника    174
# Кухонная посуда                         138
# Name: Популярная_категория, dtype: int64
#
# текущий_месяц          1300
# предыдущий_месяц       1300
# препредыдущий_месяц    1300
# Name: Период, dtype: int64
#
# предыдцщий_месяц    1300
# текущий_месяц       1300
# Name: Период, dtype: int64

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>1. Видно, что "Покупательская активность" распределена 2:1<br>
#     2. В "Тип сервиса" ошибка в категории. Заменю "стандартт" на "стандарт".<br>
#     3. В market_money есть в "Период" категория "препредыдущий_месяц". Предполагаю это как перед предыдущим. Потому оставлю<br>
#     4. В market_time есть опечатка. Исправлю "предыдцщий_месяц" на "предыдущий_месяц"</font>
# </div>

# %%
market_file['Тип сервиса'].replace('стандартт', 'стандарт', inplace=True)
market_time['Период'].replace('предыдцщий_месяц', 'предыдущий_месяц', inplace=True)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Значения категориальных признаков содержат ошибки - нужно исследовать их и исправить. Ниже ты делаешь это по ходу EDA, но структурно правильнее сделать это до начала анализа.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных

# %%
market_file.head()
# Out:
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась    стандарт                нет
# 3  215351                 Снизилась    стандарт                 да
# 4  215352                 Снизилась    стандарт                нет
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
#   Популярная_категория  Средний_просмотр_категорий_за_визит  \
# ...

# %%
# Перезаписываю, так как у money столбец поменял тип на float
df_list = [market_file, market_money, market_time, money]
for df_l in df_list:
    num_columns = df_l.drop('id', axis=1).select_dtypes(include='number').columns
    display(df_l[num_columns].describe())
    print()
# Out:
#        Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# count         1300.000000           1300.000000   1300.000000
# mean             4.253769              4.011538    601.898462
# std              1.014814              0.696868    249.856289
# min              0.900000              3.000000    110.000000
# 25%              3.700000              4.000000    405.500000
# 50%              4.200000              4.000000    606.000000
# 75%              4.900000              4.000000    806.000000
# max              6.600000              5.000000   1079.000000
#
#        Акционные_покупки  Средний_просмотр_категорий_за_визит  \
# count        1300.000000                           1300.00000
# mean            0.319808                              3.27000
# std             0.249843                              1.35535
# min             0.000000                              1.00000
# 25%             0.170000                              2.00000
# ...

# %% [markdown]
# ### market_file

# %%
cat = ['Покупательская активность', 'Тип сервиса', 'Разрешить сообщать',
      'Маркет_актив_тек_мес', 'Популярная_категория', 'Средний_просмотр_категорий_за_визит',
      'Неоплаченные_продукты_штук_квартал', 'Ошибка_сервиса', 'Страниц_за_визит']
num_col = ['Маркет_актив_6_мес', 'Длительность', 'Акционные_покупки']

# %%
for i in cat:
    sns.countplot(x=i, data=market_file, palette='Set2')
    plt.show()
#sns.countplot(market_file, x="Тип сервиса", hue="Покупательская активность")

# %%
def hist_boxplot(df, column):
    plt.figure(figsize=(10, 6))
    plt.subplot(1, 2, 1)
    plt.xlabel(f'Значения столбца {column}')
    plt.ylabel('Частота')
    plt.title(f'Гистограмма для {column}')
    sns.histplot(df[column])
    plt.subplot(1, 2, 2)
    plt.xlabel(f'Значения столбца {column}')
    plt.title(f'Диаграмма размаха для {column}')
    sns.boxplot(x=df[column])

# %%
for name in num_col:
    hist_boxplot(market_file, name)

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Метод `.print()` не очень подходит для работы с таблицами типа `pd.DataFrame`, так как выводит их на экран просто как отформатированный текст. Для отображения небольших таблиц можно воспользоваться методом `.head()`, для таблиц побольше - модулем `display`.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Для анализа дискретных признаков нужнен тип графиков, который на каждое уникальные значение признака строит свою корзину. Например, можно использовать `sns.countplot`.
#
# Для этих признаков также не нужно строить ящики с усами, так как признак имеет, скорее, распределение категориального признака, пусть и представленного уже в численном виде.
#
# Дискретность признака определяется либо числом уникальных значений (обычно не более 20), либо отсутствием дробной части (дискретный признак всегда целочисленный).

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Тут актуально.

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Перенес ряд полей, чтобы пополнить категоральные параметры </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ### market_money

# %%
for name in market_money.drop('id', axis=1).select_dtypes(include='number').columns:
    hist_boxplot(market_money, name)

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>1. Есть один клиент, который принес много прибыли магазину. Такое вполне возможно. Стоит ли его оставить (боюсь, что будет искажать результаты) или удалить...?<br>
#     2. Какие то странные значения прибыли в Датафрейме money. Как средняя прибыль за 3 месяца может быть такой маленькой? В чем измеряется? </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b> Да, нужно удалить аномального клиента. По поводу низкой выручки - вряд ли смогу ответить на вопрос, сценарии для низкой выручки могут быть разными.

# %%
l = [75, 80, 85, 90, 95, 97, 98, 99]
for i in l:
    print(np.percentile(market_money['Выручка'], i))
# Out:
# 5363.0
# 5492.0
# 5636.575
# 5871.55
# 6226.525
# 6457.943999999999
# 6649.974
# 6957.736999999999

# %%
more_99 = np.percentile(market_money['Выручка'], 99.99)

# %%
market_money.query('Выручка > @more_99')
# Out:
#         id         Период   Выручка
# 98  215380  текущий_месяц  106862.2

# %%
id_drop = market_money.query('Выручка > @more_99 or Выручка <= 0')['id']

market_money = market_money.query('id not in @id_drop')

# %%
for name in market_money.drop('id', axis=1).select_dtypes(include='number').columns:
    hist_boxplot(market_money, name)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b> Обработан выброс по выручке.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Фактически ты удаляешь не пользователя, а только строку для него из `market_money`. Вместо индекса нужно получить `id` пользователя и удалить его.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b> Учтено.

# %% [markdown]
# ### market_time

# %%
for name in market_time.drop('id', axis=1).select_dtypes(include='number').columns:
    hist_boxplot(market_time, name)

# %% [markdown]
# ### money

# %%
for name in money.drop('id', axis=1).select_dtypes(include='number').columns:
    hist_boxplot(money, name)

# %%
# Юзеры, с покупательской активностью не менее 3 месяцев
users_3m = market_money.query('Выручка == 0')['id'].to_list() #Ранее были выявлены на 7.2 
users_3m
# Out:
# []

# %%
market_file = market_file.query('id not in @id_drop')
market_money = market_money.query('id not in @id_drop')
market_time = market_time.query('id not in @id_drop')
money = money.query('id not in @id_drop')

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Условие `Период == "препредыдущий_месяц` лишнее - выручка должна быть ненулевой во всех трёх периодах.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b> Учтено.

# %% [markdown]
# ### Вывод:
# Удалены выбросы из прибыли. Отредактированы разночтения признаков в данных.

# %% [markdown]
# ## Шаг 4. Объединение таблиц

# %%
full_df = market_file.copy()

# %%
market_money_period = ['препредыдущий_месяц', 
                  'предыдущий_месяц', 
                  'текущий_месяц'] 

for name in market_money_period:
    full_df = full_df.merge(market_money.query('Период == @name'), 
                          on='id', 
                          how='left', 
                          suffixes=('_препред', '_пред'))

# %%
full_df = full_df.drop(labels=['Период_препред', 
                             'Период_пред', 
                             'Период'], axis=1)

full_df = full_df.rename(columns={'Выручка':'выручка_тек'})

# %%
market_time_period = ['предыдущий_месяц', 
               'текущий_месяц'] 

#добавление новых столбцов
for name in market_time_period:
    full_df = full_df.merge(market_time.query('Период == @name'), 
                          on='id', 
                          how='left', 
                          suffixes=('_пред', '_тек'))

# %%
full_df = full_df.drop(labels=['Период_пред', 'Период_тек'], axis=1)
full_df = full_df.set_index('id')

# %%
full_df.head()
# Out:
#        Покупательская активность Тип сервиса Разрешить сообщать  \
# id
# 215349                 Снизилась     премиум                 да
# 215350                 Снизилась    стандарт                нет
# 215351                 Снизилась    стандарт                 да
# 215352                 Снизилась    стандарт                нет
# 215353                 Снизилась    стандарт                 да
#
#         Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# id
# 215349                 4.4                     4           819
# 215350                 4.9                     3           539
# 215351                 3.2                     5           896
# 215352                 5.1                     3          1064
# 215353                 3.3                     4           762
#
#         Акционные_покупки Популярная_категория  \
# id
# 215349               0.75     Товары для детей
# 215350               0.14    Домашний текстиль
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Обрати внимание, что в итоговой таблице на одного пользователя должна приходиться одна строка - текущий способ преобразования таблиц не подходит.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b> Учтено.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Пропуски нужно удалить, а не заполнить нулями - в противном случае удаление неактивных пользователей ранее не приводит к их удалению из итоговой таблицы.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b> Учтено.

# %%
"""
full_df = full_df.groupby(['id', 'Покупательская активность', 'Популярная_категория',
                           'Разрешить сообщать', 'Тип сервиса'])\
.agg({'Акционные_покупки': 'mean',
      'Выручка_предыдущий_месяц': 'sum',
      'Выручка_препредыдущий_месяц': 'sum',
      'Выручка_текущий_месяц': 'sum',
      'Длительность': 'mean',
      'Маркет_актив_6_мес': 'mean',
      'Маркет_актив_тек_мес': 'mean',
      'Минут_предыдущий_месяц': 'sum',
      'Минут_препредыдущий_месяц': 'sum',
      'Минут_текущий_месяц': 'sum',
      'Неоплаченные_продукты_штук_квартал': 'mean',
      'Ошибка_сервиса': 'mean',
      'Средний_просмотр_категорий_за_визит': 'mean',
     'Страниц_за_визит': 'mean'}).reset_index()
""";

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Это действие также некорректно - см.ранее.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b> Учтено.

# %%
market_file = market_file.set_index('id')

# %% [markdown]
# ## Шаг 5. Корреляционный анализ

# %%
full_df.head()
# Out:
#        Покупательская активность Тип сервиса Разрешить сообщать  \
# id
# 215349                 Снизилась     премиум                 да
# 215350                 Снизилась    стандарт                нет
# 215351                 Снизилась    стандарт                 да
# 215352                 Снизилась    стандарт                нет
# 215353                 Снизилась    стандарт                 да
#
#         Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# id
# 215349                 4.4                     4           819
# 215350                 4.9                     3           539
# 215351                 3.2                     5           896
# 215352                 5.1                     3          1064
# 215353                 3.3                     4           762
#
#         Акционные_покупки Популярная_категория  \
# id
# 215349               0.75     Товары для детей
# 215350               0.14    Домашний текстиль
# ...

# %%
corr_matrix = full_df.phik_matrix(interval_cols=[
    'Маркет_актив_6_мес', 'Длительность', 'Акционные_покупки',
'Выручка_препред', 'Выручка_пред', 'выручка_тек',
'минут_пред', 'минут_тек'])

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Phi_K Correlation Matrix')
plt.show()

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Видна сильная связь между признаками "выручка_тек" и "Выручка_пред"<br>
# </div>

# %% [markdown]
# ### Вывод:
# Был удален признак 'Выручка_препредыдущий_месяц' из-за высокой корреляции с признаками "Выручка_предыдущий_месяц" и "Акционные_покупки". К тому же отсутствуют данные у признака 'Минут_препредыдущий_месяц', который так же был удален, но по причине отсутсвия данных

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Есть анализ корреляции - молодец, что используешь `phik` для анализа и нелинейных зависимостей, а также настраиваешь `interval_cols` для корректной оценки корреляции для переменных разного типа.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> В `interval_cols` нужно передавать только непрерывные признаки. В нашем проекте это `'маркет_актив_6_мес', 'длительность', 'акционные_покупки', 'выручка_препредыдущий_месяц', 'выручка_предыдущий_месяц', 'выручка_текущий_месяц'`.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ## Шаг 6. Использование пайплайнов

# %%
full_df.columns
# Out:
# Index(['Покупательская активность', 'Тип сервиса', 'Разрешить сообщать',
#        'Маркет_актив_6_мес', 'Маркет_актив_тек_мес', 'Длительность',
#        'Акционные_покупки', 'Популярная_категория',
#        'Средний_просмотр_категорий_за_визит',
#        'Неоплаченные_продукты_штук_квартал', 'Ошибка_сервиса',
#        'Страниц_за_визит', 'Выручка_препред', 'Выручка_пред', 'выручка_тек',
#        'минут_пред', 'минут_тек'],
#       dtype='object')

# %%
#le = LabelEncoder()
#le.fit(full_df['Покупательская активность'])
#full_df['Покупательская активность_номер'] = le.transform(full_df['Покупательская активность'])

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Кодирование данных нужно осуществлять только после сплитования - так мы не допускаем утечку данных из тестовой части, а также можем контролировать появление в `test` новых значений категориальных признаков.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    full_df.drop(['Покупательская активность'], axis=1),
    full_df['Покупательская активность'],
    test_size = 0.25, 
    random_state = 42,
    stratify = full_df['Покупательская активность'])

# %%
#кодирование целевого признака
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Сплитование выполнено корректно. Молодец, что делаешь стратификацю целевого признака - в выборках будет равное соотношение классов, что может привести к росту качества твоего решения.

# %%
X_train.shape
# Out:
# (972, 16)

# %%
# создаём списки с названиями признаков
ohe_columns = ['Популярная_категория']
num_columns = ['Маркет_актив_6_мес', 'Маркет_актив_тек_мес', 
               'Длительность', 'Акционные_покупки', 'Средний_просмотр_категорий_за_визит',
              'Неоплаченные_продукты_штук_квартал', 'Ошибка_сервиса', 'Страниц_за_визит',
              'Выручка_препред', 'Выручка_пред',
              'выручка_тек', 'минут_пред', 'минут_тек']
ord_columns = ['Тип сервиса', 'Разрешить сообщать']

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> `Разрешить сообщать` - также упорядоченный признак, который нужно кодировать с помощью `OrdinalEncoder`.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Инструменты масштабирования можно исследовать методом перебора, но не применять к одним и тем же данным другм за другом.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))
    ]
    )

# %%
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                categories=[
                    ['стандарт', 'премиум'],
                    ['нет', 'да']
                ], 
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# %%
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', StandardScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %%
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=42))
])

# %%
param_grid = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=42)],
        'models__max_depth': range(2, 7),
        'models__max_features': range(2, 7),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 15),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(
            random_state=42, 
            solver='liblinear'
        )],
        'models__C': range(1, 7),
        'models__penalty': ['l1', 'l2'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели SVC()
    {
        'models': [SVC(random_state=42, probability=True)], 
        'models__C': [0.1, 1,10], 
        'models__kernel': ['linear', 'rbf'],
        #'models__decision_function_shape': ['ovo', 'ovr'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    }
]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> У `SVC` нужно настроить параметр, отвечающий за работу с вероятностями, для корректной оценки метрики `AUC-ROC`.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
grid = GridSearchCV(
    pipe_final, 
    param_grid=param_grid, 
    cv=5, 
    scoring='roc_auc', #выбираю метрику roc_auc, тк есть дисбаланс классов и метрика позволяет не зависеть от конкретного порога
    n_jobs=-1
)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Выбор метрики нужно обосновать более уверенно. `f1` - метрика, которая чувствительна к дисбалансу, поэтому текущее обоснование не годится.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ohe',
#                                                                          Pipeline(steps=[('simpleImputer_ohe',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('ohe',
#                                                                                           OneHotEncoder(drop='first',
#                                                                                                         handle_unknown='ignore',
#                                                                                                         sparse_output=False))]),
# ...

# %%
print(f'Метрика roc_auc для лучшей модели: {grid.best_score_}')
print('\nЛучшая модель и её параметры:\n\n', grid.best_estimator_)
# Out:
# Метрика roc_auc для лучшей модели: 0.9110794902340356
#
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['Популярная_категория']),
#                                                  ('ord',
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Найдена лучшая модель.

# %%
result = pd.DataFrame(grid.cv_results_)
display(result[
    ['rank_test_score', 'param_models', 'mean_test_score','params']
].sort_values('rank_test_score'))
# Out:
#      rank_test_score                                       param_models  \
# 153                1             SVC(probability=True, random_state=42)
# 159                2             SVC(probability=True, random_state=42)
# 160                3             SVC(probability=True, random_state=42)
# 154                4             SVC(probability=True, random_state=42)
# 115                5  LogisticRegression(random_state=42, solver='li...
# ..               ...                                                ...
# 4                163            DecisionTreeClassifier(random_state=42)
# 3                163            DecisionTreeClassifier(random_state=42)
# 8                166            DecisionTreeClassifier(random_state=42)
# 7                166            DecisionTreeClassifier(random_state=42)
# 6                166            DecisionTreeClassifier(random_state=42)
#
#      mean_test_score                                             params
# ...

# %%
grid.best_params_
# Out:
# {'models': SVC(probability=True, random_state=42),
#  'models__C': 0.1,
#  'models__kernel': 'rbf',
#  'preprocessor__num': StandardScaler()}

# %%
y_pred = grid.best_estimator_.predict_proba(X_test)

# %%
print(f'Метрика ROC-AUC на тестовой выборке: {round(roc_auc_score(y_test, y_pred[:, 1]), 4)}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.9112

# %% [markdown]
# ### Вывод:
# Лучше всего себя показала модель SVC со значением roc_auc = 0.911<br><br>
# Параметрый модели {'models': SVC(probability=True, random_state=42),
#  'models__C': 0.1,
#  'models__kernel': 'rbf',
#  'preprocessor__num': StandardScaler()}<br><br>
#  На тестовых данных roc_auc = 0.895

# %% [markdown]
# ## Шаг 7. Анализ важности признаков

# %%
X_test_transformed = grid.best_estimator_['preprocessor'].fit_transform(X_train)

model = grid.best_estimator_['models'].fit(X_test_transformed, y_train)
explainer = shap.PermutationExplainer(model, X_test_transformed)


labels = grid.best_estimator_[:-1].get_feature_names_out()

shap.summary_plot(X_test_transformed, plot_type='bar', feature_names=labels, show=False) 
fig, ax = plt.gcf(), plt.gca()
ax.tick_params(labelsize=14)
cb_ax = fig.axes[0]
cb_ax.tick_params(labelsize=15)
ax.set_title('Feature Importance SHAP', fontsize=16)
cb_ax.set_ylabel("Feature_value", fontsize=20)

plt.show()

# %% [markdown]
# ### Вывод:
# Малозначимые признаки для модели - признаки о популярных категориях товаров и другие: "Популярная_категория_Кухонная посуда", "Маркет_актив_тек_мес", "Популярная_категория_Косметика и аксесуары", "Тип сервиса"<br>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Здорово, что используешь `SHAP` для анализа важности признаков.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Не забывай подписывать ось Y и название на графике. Так как `SHAP` график тоже является визуальным объектом, для его кастомизации мы можем использовать методы plt, как и для других графиков, однако это потребует небольшой настройки самого объекта `SHAP`. Подробнее можно глянуть тут: https://github.com/shap/shap/issues/594.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2  <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Не хватает названия.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ## Шаг 8. Сегментация покупателей

# %%
#y_pred_proba = grid.best_estimator_.predict_proba(X_test)

# %%
#print("roc_auc:", roc_auc_score(y_test, y_pred[:, 1]))

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Давай вспомним, что из себя представляет метрика `AUC-ROC` и подходит ли метод `predict` для её оценки?

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> В ячейке `59` используется старый вариант `y_pred` вместо `y_pred_proba`, аналогичная ошибка в ячейке `55`.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
# Очень важно также проверить лучшую модель на адекватность, сравнив качество её предсказаний с качеством модели, которая предсказывала бы константу - вдруг окажется, что не было бы большого смысла заниматься созданием новых признаков, тюнингом и кросс-валидацией моделей, если можно было бы просто предсказывать среднее значение тренировочной выборки?
#
# В качестве константной модели можно использовать `DummyClassifier` (https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyClassifier.html#sklearn.dummy.DummyClassifier) -  эта модель как раз создана для генерирования константных предсказаний.
#
# Важно, чтобы результат тестирования нашей модели на тествой выборке был лучше, чем результат константной модели - в противном случае наша модель является бесполезной, так как все наши усилия над проектом не принесли результата, а можель, просто предсказывющая среднее на `train`, делает нашу работу лучше.
#
# Константная модель оценивается так же, как и любая другая модель - обучаем её на `train`, делаем предсказания для `test` и оцениваем их качество. Ничего сложного, я уверен, у тебя получится, а наличие проверки на адекватность повышает ценность твоего исследования:)

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
dummy_clf = DummyClassifier(strategy="most_frequent", random_state=42)
dummy_clf.fit(X_train, y_train)

y_pred_dummy = dummy_clf.predict(X_test)


roc_auc_dummy = roc_auc_score(y_test, y_pred_dummy)
accuracy_dummy = accuracy_score(y_test, y_pred_dummy)

y_pred_model = grid.predict(X_test)
roc_auc_model = roc_auc_score(y_test, y_pred_model)
accuracy_model = accuracy_score(y_test, y_pred_model)


print("roc_auc score константной модели (DummyClassifier):", roc_auc_dummy)
print("roc_auc score подобранной модели:", roc_auc_model)
print("Точность константной модели (DummyClassifier):", accuracy_dummy)
print("Точность подобранной модели:", accuracy_model)


if roc_auc_model > roc_auc_dummy:
    print("Подобранная модель превосходит константную модель по roc_auc score.")
else:
    print("Константная модель оказалась лучше")
# Out:
# roc_auc score константной модели (DummyClassifier): 0.5
# roc_auc score подобранной модели: 0.8949763378230797
# Точность константной модели (DummyClassifier): 0.6203703703703703
# Точность подобранной модели: 0.9166666666666666
# Подобранная модель превосходит константную модель по roc_auc score.

# %%
money = money.set_index('id')

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Для сегментации аналогично нужны вероятности снижения активности.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
#data['Покупательская активность код'] = data['Покупательская активность'].astype('category').cat.codes

# %%
"""
for name in data.select_dtypes(include='number').columns:
    plt.figure(figsize=(10, 4))
    plt.title(f'Признак "{name}"')
    plt.xlabel('Вероятность принадлежности к классу 1')
    plt.ylabel(f'Значение')
    plt.scatter(x=data['вероятность'], 
                y=data[name],
                c=data['Покупательская активность код'],
                alpha=0.5)
""";

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> С учётом анализа распределения прибыли и вероятностей снижения активности нужно выбрать значения этих признаков, по которым будет выбрана группа пользователей - сейчас твой сегмент включает всех пользователей `test` выборки, что в целом не является сегментацией.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Актуально - фактически не выполнено выделение сегмента.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Актуально. Для выделения сегмента нужно использовать границу по прибыли и вероятности снижения активности, границу нужно определить самостоятельно с учётом распределения этих величин.

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Зачем выделять сегмент именно по прибыли? Ниже я виделил сегменты по другим параметрам. Например, таким как ационные покупки и категория "детские товары и минуты на сайте.<br>
#         Признак "прибыль" не дает выделить порог, как и остальные параметры с прибылью. Разве что "Выручка_препред" немного выделяется. Сделаю на ней акцент.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.4 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> См.условие проекта: `8.1 Выполните сегментацию покупателей. Используйте результаты моделирования и данные о прибыльности покупателей`. Использование данных о прибыли для выделение сегмента - обязательное условие проекта, которое должно быть учтено.
#
# Таким образом, в выделение сегмента тебе нужно использовать как минимум вероятность и прибыль, а сверху уже можно накидывать дополнительные условия (при желании).

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Если я верно понял комментарий, то:<br><br>
#         Добавил окрас для каждого пользователя, чтобы в итоге видеть снизилась активность или осталась прежней. Это позволило определить порог вероятности по денежным метрикам (Выручка_препред, Выручка_пред, выручка_тек, Прибыль), равный около 0.6. А так же, "Выручка_препред" ниже 5000. В том числе построил диаграмму рассеяния для категории выше 5000 за препредыдущий месяц выручка или нет<br><br>
#         См.ниже
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.5 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Ты всё ещё не используешь прибыль и вероятность для выделения сегмента. Давай следовать строго по шагам:
#
# 1. В `X_test` добавляем информацию по прибыли, используя `id` как ключ для соединения.
#
# 2. Аналогичным образом добавляем вероятность снижения активности (уже не по ключу, а через обычное присваивание).
#
# 3. Строим графики распределения прибыли и вероятности.
#
# 4. Анализируем графики, выбираем границы сегмента с учётом этого анализа.
#
# 5. `temp_date` формируем как срез из `X_test` по двум условиям: прибыль в диапазоне и вероятность в диапазоне. Диапазоны определяем на основе п.4.
#
# 6. Проводим EDA `temp_date`.
#
# Обрати внимание, что в `X_test` нужно корректно добавить `id` - сейчас ты выполняешь `X_test.sort_values(by='вероятность', ascending=False)`, а потом делаешь `join` с `market_file[['id']]` - это не будет работать корректно, так как за счёт `sort_values` ты перемешиваешь индексы таблицы, и `join` будет выполнен неправильно. Тут лучше всего будет сделать `id` индексом у `market_file` - тогда после `train_test_split` у `X_test` уже будет правильный индекс, и `join` будет работать верно.
#
# Обрати также внимание, что у нас осталась последняя итерация - обратись за помощью к преподавателю, если из последовательности шагов выше будет что-то непонятно.

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>1. Сделал id индексом<br>
#         2. Добавил вероятность<br>
#         3. Построил графики (ячейки 68 и 69)<br>
#         4. Порог вероятности от 0.8. По прибыли порог заметен только в Выручка_препред - меньше 5000.<br>
#         5. В temp_date сохранен срез data.query('Выручка_препред < 5000 and вероятность > 0.81')
# </div>

# %%
X_test['вероятность'] = y_pred[:, 1]
X_test = X_test.join(money, how='left')
X_test = X_test.join(market_file[['Покупательская активность']], how='left')
data = X_test.copy()

# %%
data['Покупательская активность'] = data['Покупательская активность'].astype('category')
data.head()
# Out:
#        Тип сервиса Разрешить сообщать  Маркет_актив_6_мес  \
# id
# 216161    стандарт                 да                 4.1
# 215654     премиум                нет                 1.4
# 216307     премиум                 да                 3.3
# 215501     премиум                 да                 3.5
# 215934    стандарт                нет                 5.5
#
#         Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# id
# 216161                     4           606               0.15
# 215654                     4           684               0.94
# 216307                     4           488               0.13
# 215501                     3          1057               0.35
# 215934                     4           147               0.99
#
#                         Популярная_категория  \
# id
# 216161        Техника для красоты и здоровья
# 215654                      Товары для детей
# 216307                     Домашний текстиль
# ...

# %%
#data = data.join(market_file[['id']], how='inner')
#data = data.merge(money, on='id', how='left')
#data.head()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data=data, x='Прибыль', hue='Покупательская активность', kde=True, multiple='stack')
plt.title('Распределение прибыли с учетом покупательской активности')
plt.xlabel('Прибыль')
plt.ylabel('Плотность')
plt.show()

# Гистограмма распределения вероятности снижения активности с учетом Покупательской активности
plt.figure(figsize=(10, 5))
sns.histplot(data=data, x='вероятность', hue='Покупательская активность', kde=True, multiple='stack')
plt.title('Распределение вероятности снижения активности с учетом покупательской активности')
plt.xlabel('Вероятность')
plt.ylabel('Плотность')
plt.show()

# %%
num_col = ['Выручка_препред', 'Выручка_пред',
          'выручка_тек', 'минут_пред', 'минут_тек', 'Прибыль']
for col in num_col:
    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=data, x='вероятность', y=col, hue='Покупательская активность', alpha=0.7)
    plt.title(f'Зависимость {col} от вероятности снижения активности с учетом покупательской активности')
    plt.xlabel('Вероятность снижения активности')
    plt.ylabel(f'{col}')
    plt.legend(title='Покупательская активность')
    plt.show()

# %%
temp_date = data.query('Выручка_препред < 5000 and вероятность > 0.81')
temp_date['Покупательская активность код'] = pd.factorize(temp_date['Покупательская активность'])[0];
#temp_date['Препред_5000'] = temp_date.apply(lambda x: 1 if x['Выручка_препред'] > 5000 else 0,axis=1)
# Out:
# /tmp/ipykernel_208/558090640.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_date['Покупательская активность код'] = pd.factorize(temp_date['Покупательская активность'])[0];

# %%
temp_date.head()
# Out:
#        Тип сервиса Разрешить сообщать  Маркет_актив_6_мес  \
# id
# 215654     премиум                нет                 1.4
# 215501     премиум                 да                 3.5
# 215844     премиум                 да                 4.3
# 215375     премиум                 да                 3.0
# 215452    стандарт                 да                 3.8
#
#         Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# id
# 215654                     4           684               0.94
# 215501                     3          1057               0.35
# 215844                     4          1041               0.99
# 215375                     4           558               0.89
# 215452                     4           756               0.90
#
#        Популярная_категория  Средний_просмотр_категорий_за_визит  \
# id
# 215654     Товары для детей                                    3
# 215501    Домашний текстиль                                    4
# ...

# %%
num_col = ['Маркет_актив_6_мес', 'Длительность', 'Акционные_покупки', 'Выручка_препред', 'Выручка_пред',
          'выручка_тек', 'минут_пред', 'минут_тек', 'Прибыль']
for name in num_col:
    plt.figure(figsize=(10, 4))
    plt.title(f'Признак "{name}"')
    plt.xlabel('Вероятность принадлежности к классу 1')
    plt.ylabel('Значение')
    
    scatter = plt.scatter(
        x=temp_date['вероятность'], 
        y=temp_date[name],
        c=temp_date['Покупательская активность код'],
        alpha=0.5,
        cmap='viridis'  
    )
    
    plt.colorbar(scatter, label='Покупательская активность')
    plt.show()

# %% [markdown]
# "Выручка_препред" ниже 5000<br>
# Можно выделить сегмент покупателей, которые покупают во основном акционные товары, то есть со значениями более 0.81, поскольку активность таких покупателей снизилась на последнее время.<br>

# %%
#df = data.query('Выручка_препред < 5000')

# %%
# Переопределю, тк в этот раз без целевого признака 
cat = ['Тип сервиса', 'Разрешить сообщать',
      'Маркет_актив_тек_мес', 'Популярная_категория', 'Средний_просмотр_категорий_за_визит',
      'Неоплаченные_продукты_штук_квартал', 'Ошибка_сервиса', 'Страниц_за_визит']
num_col = ['Маркет_актив_6_мес', 'Длительность', 'Акционные_покупки']

# %%
for name in num_col:
    hist_boxplot(temp_date, name)

# %%
for i in cat:
    sns.countplot(x=i, data=temp_date, palette='Set2')
    plt.title(f'Распределение категории "{i}"')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> На графиках выше не хватает названия.

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Добавил заголовки<br>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.4 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Чаще всего клиенты из этой категории покупают детские товары и из категории домашнего текстиля.

# %%
num_col = ['Маркет_актив_6_мес', 'Длительность', 'Акционные_покупки', 'Выручка_препред', 'Выручка_пред',
          'выручка_тек', 'минут_пред', 'минут_тек']
for name in num_col:
    plt.figure(figsize=(15,5))
    plt.subplot(1, 2, 1)
    plt.title(f'Гистограмма для "{name}"')
    sns.histplot(data=full_df.query('Популярная_категория == "Товары для детей" and Выручка_препред < 5000'),
                 x=name, hue='Покупательская активность',
                stat='density', common_norm=False)
    plt.xlabel(f'Значение параметра "{name}"')
    plt.ylabel('Плотность')
    
    plt.subplot(1, 2, 2)
    plt.title(f'Диаграмма размаха дляname"{name}"')
    sns.boxplot(x='Покупательская активность', y=name, 
                data=full_df.query('Популярная_категория == "Товары для детей" and Выручка_препред < 5000'));
    plt.ylabel(f'Значение параметра "{name}"')

# %%
for i in cat:
    sns.countplot(x=i, data=full_df.query('Популярная_категория == "Товары для детей" and Выручка_препред < 5000'),
                  palette='Set2')
    plt.title(f'Распределение категории "{i}"')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# 1. В части дискретных признаков см.замечание ранее - обычная гистограмма не подходит для их анализа.
#
# 2. При анализе непрерывного признака в разрезе целевого нужно использовать нормированную гистограмму (например, `shs.histplot()` с параметрами `stat='density', common_norm=False` или `sns.kdeplot()`): гистограммы такого типа позволяют нивелировать разницу в размерах выборок при анализе распределений. Обрати также внимание, что при использовании нормированных гистограмм по оси Y будет уже не частота значений, а плотность распределения.

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Сначала построил графики с предложенными параметрами для histplot для покупателей с выручкой за препредыдущий месяц менее 5000. Потом добавил условие на категорию товаров "Для детей". <br>
#         Две серии графиков
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.4 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> На нормированных гистограммах нужно скорректировать подпись оси Y.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.5 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Покупатели, у которых выручка за препредыдущий месяц менее 5000 и у которых снизилась покупательская активность:
# 1. В основном покупают во время акций
# 2. Практически не рассматривают другие категори за визит (2-3)
# 3. Просматривают мало страниц (в основном до 5)
# 4. Проводят меньше времени на сайте, чем покупатели, у которых активность осталась на прежнем уровне.<br><br>
#
#
# Возможно стоит чаще проводить акции на детские товары и уведомлять об этом таких пользователей

# %% [markdown]
# ### Вывод:
# На основании графиков бросаются в глаза следующие пороги значений признака для разделения покупателей на классы. В частности, покупатели со сниженной активностью имеют значения признака:<br><br>
#
#  - "Маркет_актив_6_мес" 4 и менее (в большинстве);
#  - "Акционные_покупки" выше 0.6;
#  - "Средний_просмотр_категорий_за_визит" менее 3;
#  - "Неоплаченные_продукты_штук_квартал" более 5;
#  - "Страниц_за_визит" менее 7;
#  - "Выручка_препред" ниже 5000;
#  - "минут_пред" ниже 14;
#  - "мину_тек" ниже 15.
#
# Основной сегмент:
#  - Категория "Товары для детей"
#  - Просмотр 2-3 категорий за визит
#  - Просмотр малого количества страниц за визит (до 5)
#  - Проводят на сайте мало времени
#  - "Выручка_препред" ниже 5000
#
# Предложения по работе с сегментом:<br>
#
# Персонализированные предложения: Например, отправка предложений на основе их предыдущих покупок и более частые персонализированные акции.
#
# Программы лояльности: Создать систему бонусов или кэшбэка за покупательскую активность, чтобы увеличить их приверженность к бренду и, возможно, привить им поведение покупать не только по акциям.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Результат сегментации корректный.

# %% [markdown]
# ## Шаг 9. Общий вывод

# %% [markdown]
# 1. Задача: Определить уровень финансовой активности постоянных покупателей на следующий месяц.
# 2. Входные данные включали показатели покупок, прибыльность клиентов, долю акционных товаров в покупках, а также другие количественные и категориальные признаки.<br>
#
# Предобработка данных включала следующие шаги:<br>
# Обработка пропущенных значений с помощью SimpleImputer.<br>
# Преобразование категориальных признаков с помощью OneHotEncoder для переменных с номинальными значениями и OrdinalEncoder для упорядоченных признаков.<br>
# Масштабирование количественных признаков с использованием комбинации методов StandardScaler, MinMaxScaler, и RobustScaler.<br>
# Использование Pipeline и ColumnTransformer для создания единого процесса обработки данных.<br><br>
# 3. Для поиска лучшей модели использовались:<br>
#
# Пайплайн для объединения этапов предобработки данных и моделей.<br>
# GridSearchCV для подбора оптимальных гиперпараметров нескольких моделей, включая:<br>
# DecisionTreeClassifier<br>
# KNeighborsClassifier<br>
# LogisticRegression<br>
# SVC<br>
# Для оценки качества моделей использовалась метрика roc_auc-score, так как данные имели дисбаланс классов.<br><br>
# 4. Лучшей моделью по итогам поиска оказался SVC с параметрами: C=2, decision_function_shape='ovo'. Эта модель достигла f1-score: 0.86<br><br>
# 5. Сегмент с долей акционных покупок менее 0.4 показал стабильность в покупательском поведении. Эти клиенты не реагируют на акционные предложения, но сохраняют свою покупательскую активность на прежнем уровне. Проведённая сегментация и анализ позволили выявить, что акционные предложения не всегда играют ключевую роль в удержании клиентов. Важно ориентироваться на долгосрочную ценность и индивидуальный подход для сохранения покупательской активности (например, персонализированные предложения и программы лояльности, стимулирование клиентов через бонусы)<br>
# 6. Стоит обращать на следующие пороги для подозрения на снижение активности покупателей:
# - "Маркет_актив6мес" 4 и менее (в большинстве);
# - "Акционные_покупки" выше 0.81;
# - "Средний_просмотр_категорий_за_визит" менее 3;
# - "Неоплаченные_продукты_штук_квартал" более 5;
# - "Страниц_за_визит" менее 7;
# - "Выручка_препред" ниже 5000;
# - "минут_пред" ниже 14;
# - "мину_тек" ниже 15.<br><br>
#
# В чавстности на сегмент:
#  - Категория "Товары для детей"
#  - Просмотр 2-3 категорий за визит
#  - Просмотр малого количества страниц за визит (до 5)
#  - Проводят на сайте мало времени

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Александр, проект получился на довольно хорошем уровне - отличная работа над проектом, молодец!
#
# Мне нравится твой аналитический подход к выполнению проекта, ты соблюдаешь структуру работы, выполняешь её последовательно - это очень хорошо! Шаги проекта выполнены по порядку согласно плану проекта, нет смысловых и структурных ям. Важно, что не забываешь про выводы.
#
# Работа с моделями также выполнена отлично: исследовано несколько алгоритмов, проведён подбор гиперпараметров с помощью `GridSearchCV`, выполнена промежуточная оценка моделей на кросс-валидации - молодец! Здорово, что используешь сочетание `ColumnTransformer` и `Pipeline` для соединения разных инструментов в единый модельный объект и настраиваешь бесперебойную работу энкодера в случае появления в данных новых, неизвестных на момент обучения значений признаков - так твоё решение будет более гибким и масштабируемым.
#
# Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: ограничение итераций.
#
# Александр, обращаю внимание, что у нас осталось 2 попытки на сдачу проекта - в противном случае нужно будет закончить проект в другой когорте.
#
# Если какие-то замечания вызывают непонимание или сложности, не забывай задавать вопросы мне в комментариях или преподавателю/наставнику (второй вариант будет более эффективен, так как на общение с преподавателем/наставником не тратятся итерации, а ответы поступают более оперативно).
